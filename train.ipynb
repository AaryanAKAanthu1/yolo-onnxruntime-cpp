# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="3LsgbPu57Zr83eqYnvrF")
project = rf.workspace("new-workspace-fazdx").project("personfactory")
version = project.version(13)
dataset = version.download("yolov11")

# %%
# Install or upgrade the ultralytics package from PyPI
# !pip install -U ultralytics

# %%
# !yolo detect train data=/content/PersonFactory-13/data.yaml model=yolo11s epochs=50 imgsz=640 device=-1 batch=32 optimizer=AdamW save=True
